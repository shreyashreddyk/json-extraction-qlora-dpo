# %% [markdown]
# # 05 Inference Benchmarks
#
# Purpose: run the in-process vLLM benchmark path inside the Colab runtime and mirror final small reports back into the repo when desired.

# %%
# !python /content/drive/MyDrive/json-ft-runs/workspace/scripts/benchmark_vllm.py \
    --config /content/drive/MyDrive/json-ft-runs/workspace/configs/inference.yaml \
    --run-name vllm-colab-benchmark \
    --runtime-root /content/drive/MyDrive/json-ft-runs \
    --model-name-or-path placeholder-model \
    --dataset-path /content/drive/MyDrive/json-ft-runs/data/heldout_eval.jsonl \
    --mirror-metrics-to-repo \
    --mirror-report-to-repo
